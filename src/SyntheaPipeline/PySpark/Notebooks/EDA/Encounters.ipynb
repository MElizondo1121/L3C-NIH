# %%
#importing libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Encounters (Visits)

# %%
df_encounters = pd.read_csv('../../synthea-sample-data/data/10k_synthea_covid19_csv/encounters.csv')
df_encounters
# Out:
#                                           Id                 START  \
# 0       d5ee30a9-362f-429e-a87a-ee38d999b0a5  2019-02-16T01:02:32Z
# 1       6a74fdef-2287-44bf-b9e7-18012376faca  2019-08-02T01:02:32Z
# 2       8bca6d8a-ab80-4cbf-8abb-46654235f227  2019-10-31T01:02:32Z
# 3       821e57ac-9304-46a9-9f9b-83daf60e9e43  2020-01-31T01:02:32Z
# 4       681c380b-3c84-4c55-80a6-db3d9ea12fee  2020-03-02T01:02:32Z
# ...                                      ...                   ...
# 321523  9af81365-e947-43b6-b4af-b94efb9182c5  2020-05-19T06:03:58Z
# 321524  823b575f-79ce-4946-917a-f7989c0de848  2020-05-26T06:03:58Z
# 321525  d4e1c9e6-2b5e-43a5-9fad-cef200c9e5c5  2020-05-22T06:03:58Z
# 321526  f69323ee-fc33-45ff-94ba-914acde61601  2020-05-22T06:03:58Z
# 321527  874117a4-16a4-4b86-b268-b8b9e7e72af7  2020-05-25T06:03:58Z
#
#                         STOP                               PATIENT  \
# 0       2019-02-16T01:17:32Z  f0f3bc8d-ef38-49ce-a2bd-dfdda982b271
# ...

# %%
df_encounters = df_encounters.convert_dtypes()
print(df_encounters.dtypes)
df_encounters.isnull().sum()
# Out:
# Id                      string
# START                   string
# STOP                    string
# PATIENT                 string
# ORGANIZATION            string
# PROVIDER                string
# PAYER                   string
# ENCOUNTERCLASS          string
# CODE                     Int64
# DESCRIPTION             string
# BASE_ENCOUNTER_COST    Float64
# TOTAL_CLAIM_COST       Float64
# PAYER_COVERAGE         Float64
# REASONCODE             Float64
# REASONDESCRIPTION       string
# dtype: object
# Id                          0
# START                       0
# STOP                        0
# PATIENT                     0
# ORGANIZATION                0
# PROVIDER                    0
# PAYER                       0
# ENCOUNTERCLASS              0
# CODE                        0
# DESCRIPTION                 0
# BASE_ENCOUNTER_COST         0
# TOTAL_CLAIM_COST            0
# PAYER_COVERAGE              0
# REASONCODE             250276
# REASONDESCRIPTION      250276
# ...

# %%
cols = ['CODE', 'DESCRIPTION']
enc = df_encounters[cols].drop_duplicates()
print(enc['CODE'].nunique())
enc['DESCRIPTION'].nunique()
# Out:
# 48
# 56
