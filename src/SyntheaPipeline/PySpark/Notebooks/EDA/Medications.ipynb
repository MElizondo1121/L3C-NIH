# %%
#importing libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Medications (Drugs)

# %%
df_medications = pd.read_csv('../../synthea-sample-data/data/10k_synthea_covid19_csv/medications.csv')
df_medications
# Out:
#              START        STOP                               PATIENT  \
# 0       2019-10-30  2019-11-13  f0f3bc8d-ef38-49ce-a2bd-dfdda982b271
# 1       2019-10-30  2019-11-13  f0f3bc8d-ef38-49ce-a2bd-dfdda982b271
# 2       2020-02-12  2020-02-26  067318a4-db8f-447f-8b6e-f2f61e9baaa5
# 3       2020-04-28  2020-05-08  067318a4-db8f-447f-8b6e-f2f61e9baaa5
# 4       2010-11-22  2011-08-30  ae9efba3-ddc4-43f9-a781-f72019388548
# ...            ...         ...                                   ...
# 431257  2020-05-13  2020-05-13  2712205f-755e-4897-acb3-926895b7d635
# 431258  2020-05-16  2020-05-16  2712205f-755e-4897-acb3-926895b7d635
# 431259  2020-05-19  2020-05-19  2712205f-755e-4897-acb3-926895b7d635
# 431260  2020-05-22  2020-05-22  2712205f-755e-4897-acb3-926895b7d635
# 431261  2020-05-25  2020-05-25  2712205f-755e-4897-acb3-926895b7d635
#
#                                        PAYER  \
# 0       7c4411ce-02f1-39b5-b9ec-dfbea9ad3c1a
# ...

# %%
df_medications = df_medications.convert_dtypes()
print(df_medications.dtypes)
df_medications.isnull().sum()
# Out:
# START                 string
# STOP                  string
# PATIENT               string
# PAYER                 string
# ENCOUNTER             string
# CODE                   Int64
# DESCRIPTION           string
# BASE_COST            Float64
# PAYER_COVERAGE       Float64
# DISPENSES              Int64
# TOTALCOST            Float64
# REASONCODE           Float64
# REASONDESCRIPTION     string
# dtype: object
# START                     0
# STOP                  28291
# PATIENT                   0
# PAYER                     0
# ENCOUNTER                 0
# CODE                      0
# DESCRIPTION               0
# BASE_COST                 0
# PAYER_COVERAGE            0
# DISPENSES                 0
# TOTALCOST                 0
# REASONCODE           100130
# REASONDESCRIPTION    100130
# dtype: int64

# %%
cols = ['START', 'STOP','REASONCODE','REASONDESCRIPTION', 'CODE', 'DESCRIPTION']
meds = df_medications[cols].drop_duplicates()
print(meds['CODE'].nunique())
print(meds['DESCRIPTION'].nunique())
meds
# Out:
# 169
# 176
#              START        STOP  REASONCODE  \
# 0       2019-10-30  2019-11-13        <NA>
# 1       2019-10-30  2019-11-13        <NA>
# 2       2020-02-12  2020-02-26        <NA>
# 3       2020-04-28  2020-05-08  43878008.0
# 4       2010-11-22  2011-08-30  59621000.0
# ...            ...         ...         ...
# 431243  2020-04-14        <NA>        <NA>
# 431244  2020-04-14        <NA>        <NA>
# 431245  2020-04-14        <NA>        <NA>
# 431246  2020-04-14        <NA>        <NA>
# 431247  2020-04-14        <NA>        <NA>
#
#                            REASONDESCRIPTION    CODE  \
# 0                                       <NA>  308182
# 1                                       <NA>  313820
# 2                                       <NA>  313820
# 3       Streptococcal sore throat (disorder)  834061
# 4                               Hypertension  999967
# ...                                      ...     ...
# 431243                                  <NA>  897718
# ...

# %% [markdown]
# <strong>What does this tell us?</strong>.
# - We should do feature selection on not only the medications but the reasons as well
# - Seperating what medications were actually COVID related could give us insight on what medications were prescibed to assist in controlling Long COVID
