# %% [markdown]
# ### Synthetic data included:
# - **allergies**
# - careplans
# - **conditions**
# - **devices**
# - **encounters**
# - imaging_studies
# - **immunizations**
# - **medications**
# - **observations**
# - organizations
# - **patients**
# - payer_transitions
# - payers
# - **procedures**
# - providers
# - supplies
#
#
#
# **NOTE: data is selected in relation to N3C similarity and current pipeline development**

# %%
#importing libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# #### Load data selected

# %% [markdown]
# df_allergies = pd.read_csv('../synthea-sample-data/data/10k_synthea_covid19_csv/allergies.csv')
# df_devices = pd.read_csv('../synthea-sample-data/data/10k_synthea_covid19_csv/devices.csv')
# df_encounters = pd.read_csv('../synthea-sample-data/data/10k_synthea_covid19_csv/encounters.csv')
# df_procedures = pd.read_csv('../synthea-sample-data/data/10k_synthea_covid19_csv/procedures.csv')
# df_immunizations = pd.read_csv('../synthea-sample-data/data/10k_synthea_covid19_csv/immunizations.csv')
# df_medications = pd.read_csv('../synthea-sample-data/data/10k_synthea_covid19_csv/medications.csv')
# df_observations = pd.read_csv('../synthea-sample-data/data/10k_synthea_covid19_csv/observations.csv')

# %% [markdown]
# ## Patients (Person)

# %%
#Load data
df_patients = pd.read_csv('../synthea-sample-data/data/10k_synthea_covid19_csv/patients.csv')
personCol = ['Id', 'BIRTHDATE', 'DEATHDATE', 'RACE', 'ETHNICITY','GENDER', 'STATE']
df_patients = df_patients[personCol]

# %%
df_patients.isnull().sum()
# Out:
# Id               0
# BIRTHDATE        0
# DEATHDATE    10000
# RACE             0
# ETHNICITY        0
# GENDER           0
# STATE            0
# dtype: int64

# %%
df = df_patients.convert_dtypes()

# %%
df['BIRTHDATE'] = pd.to_datetime(df['BIRTHDATE']).dt.year
df['DEATHDATE'] = pd.to_datetime(df['DEATHDATE']).dt.year
df[['DEATHDATE']] = df[['DEATHDATE']].fillna(0)

# %%
df['AGE'] = np.where(df['DEATHDATE'] != 0  , 0, (2021 - df['BIRTHDATE']))

# %% [markdown]
# ### Deceased subset

# %%
df_dead = df.loc[(df['AGE'] == 0)]
df = df.loc[(df['AGE'] != 0)]

# %%
df_dead['AGE'] = (df_dead['DEATHDATE'] - df_dead['BIRTHDATE'])
df_dead
# Out:
#                                          Id  BIRTHDATE  DEATHDATE   RACE  \
# 11     58cac9ec-4baa-46c1-b919-0ed13572b51d       1970     2016.0  white
# 42     c70992c9-ff13-467b-9032-1901506edeef       1959     2020.0  white
# 62     cd7cdbef-ef08-48da-9302-19bf4b2dffa3       1940     2010.0  white
# 72     a5c39700-6bf3-4984-af46-31344695e21b       1940     2020.0  white
# 80     419c213d-8d35-440c-bf47-a536f95df517       1964     1999.0  white
# ...                                     ...        ...        ...    ...
# 12318  59cd3afd-ba9c-4753-95b3-70c761cbd454       1937     2015.0  white
# 12330  cc08ece6-5a10-454f-b1d8-830a4b02fd31       1957     2020.0  white
# 12334  7475a593-3fa7-40c2-bbdf-86c68ebce67b       1918     2014.0  white
# 12348  3daf2b90-c439-469f-bb44-fb6109c6a8a7       1918     1999.0  white
# 12349  cb03d88e-7f08-46a1-be78-70d9fe8262a7       1918     2009.0  white
#
#          ETHNICITY GENDER          STATE   AGE
# 11        hispanic      F  Massachusetts  46.0
# 42     nonhispanic      M  Massachusetts  61.0
# 62     nonhispanic      F  Massachusetts  70.0
# 72     nonhispanic      M  Massachusetts  80.0
# 80     nonhispanic      M  Massachusetts  35.0
# ...            ...    ...            ...   ...
# 12318  nonhispanic      F  Massachusetts  78.0
# 12330  nonhispanic      M  Massachusetts  63.0
# 12334  nonhispanic      F  Massachusetts  96.0
# 12348  nonhispanic      F  Massachusetts  81.0
# 12349  nonhispanic      F  Massachusetts  91.0
#
# [2352 rows x 8 columns]

# %% [markdown]
# ## Patient Demographics Visualization

# %%
sns.violinplot(x = "RACE", y = "AGE", hue = 'GENDER', data = df)
plt.title('RACE, AGE, GENDER of living patients')
plt.show()

# %% [markdown]
# sns.catplot(
#     data=df, x="RACE", y="ETHNICITY", hue="GENDER",
#     kind="violin", inner="stick", split=True, palette="pastel",
# )

# %%
sns.violinplot(x = "ETHNICITY", y = "AGE", hue = 'GENDER', data = df)
plt.title('ETHNICITY, AGE, GENDER of living patients')
plt.show()

# %%
sns.violinplot(x = "RACE", y = "AGE",pallete = 'rainbow', data = df_dead)
plt.title('RACE, AGE, GENDER of deceased patients')
plt.show()

# %%
sns.violinplot(x = "ETHNICITY", y = "AGE", hue = 'GENDER', data = df_dead)
plt.title('ETHNICITY, AGE, GENDER of deceased patients')
plt.show()

# %% [markdown]
# <break/>

# %% [markdown]
# ## Conditions (Conditions)

# %%
df_conditions = pd.read_csv('../synthea-sample-data/data/10k_synthea_covid19_csv/conditions.csv')
df_conditions
# Out:
#              START        STOP                               PATIENT  \
# 0       2019-02-15  2019-08-01  f0f3bc8d-ef38-49ce-a2bd-dfdda982b271
# 1       2019-10-30  2020-01-30  f0f3bc8d-ef38-49ce-a2bd-dfdda982b271
# 2       2020-03-01  2020-03-30  f0f3bc8d-ef38-49ce-a2bd-dfdda982b271
# 3       2020-03-01  2020-03-01  f0f3bc8d-ef38-49ce-a2bd-dfdda982b271
# 4       2020-03-01  2020-03-30  f0f3bc8d-ef38-49ce-a2bd-dfdda982b271
# ...            ...         ...                                   ...
# 114539  2020-03-04  2020-04-01  2712205f-755e-4897-acb3-926895b7d635
# 114540  2020-03-04  2020-04-01  2712205f-755e-4897-acb3-926895b7d635
# 114541  2020-03-04  2020-04-01  2712205f-755e-4897-acb3-926895b7d635
# 114542  2020-03-04  2020-03-04  2712205f-755e-4897-acb3-926895b7d635
# 114543  2020-03-04  2020-04-01  2712205f-755e-4897-acb3-926895b7d635
#
#                                    ENCOUNTER       CODE  \
# 0       d5ee30a9-362f-429e-a87a-ee38d999b0a5   65363002
# 1       8bca6d8a-ab80-4cbf-8abb-46654235f227   65363002
# 2       681c380b-3c84-4c55-80a6-db3d9ea12fee  386661006
# 3       681c380b-3c84-4c55-80a6-db3d9ea12fee  840544004
# 4       681c380b-3c84-4c55-80a6-db3d9ea12fee  840539006
# ...                                      ...        ...
# 114539  a18d0f16-bc12-4897-8844-8c3ebc2464fc  248595008
# 114540  a18d0f16-bc12-4897-8844-8c3ebc2464fc   68962001
# 114541  a18d0f16-bc12-4897-8844-8c3ebc2464fc   57676002
# 114542  a18d0f16-bc12-4897-8844-8c3ebc2464fc  840544004
# 114543  a18d0f16-bc12-4897-8844-8c3ebc2464fc  840539006
#
#                      DESCRIPTION
# 0                   Otitis media
# 1                   Otitis media
# 2                Fever (finding)
# 3             Suspected COVID-19
# 4                       COVID-19
# ...                          ...
# 114539  Sputum finding (finding)
# 114540     Muscle pain (finding)
# 114541      Joint pain (finding)
# 114542        Suspected COVID-19
# 114543                  COVID-19
#
# [114544 rows x 6 columns]

# %%
df_conditions = df_conditions.convert_dtypes()
print(df_conditions.dtypes)
df_conditions.isnull().sum()
# Out:
# START          string
# STOP           string
# PATIENT        string
# ENCOUNTER      string
# CODE            Int64
# DESCRIPTION    string
# dtype: object
# START              0
# STOP           51448
# PATIENT            0
# ENCOUNTER          0
# CODE               0
# DESCRIPTION        0
# dtype: int64

# %%
df_conditions[['START','STOP']] = df_conditions[['START','STOP']].apply(pd.to_datetime)

# %%
df_conditions.dtypes
# Out:
# START          datetime64[ns]
# STOP           datetime64[ns]
# PATIENT                string
# ENCOUNTER              string
# CODE                    Int64
# DESCRIPTION            string
# dtype: object

# %%
df_conditions['ConditionDuration'] = (df_conditions['STOP'] - df_conditions['START']).dt.days

# %% [markdown]
# ### Looking into code vs. description (1:1?)

# %%
cols = ['CODE', 'DESCRIPTION']
cond = df_conditions[cols].drop_duplicates()
cond
# Out:
#                  CODE                                        DESCRIPTION
# 0            65363002                                       Otitis media
# 2           386661006                                    Fever (finding)
# 3           840544004                                 Suspected COVID-19
# 4           840539006                                           COVID-19
# 5            44465007                                    Sprain of ankle
# ...               ...                                                ...
# 51102  60951000119105  Blindness due to type 2 diabetes mellitus (dis...
# 53205       698423002    History of disarticulation at wrist (situation)
# 61783       427089005                                   Male Infertility
# 75215        65275009                                Acute Cholecystitis
# 75216       235919008                                     Cholelithiasis
#
# [180 rows x 2 columns]

# %%
print(cond['CODE'].nunique())
cond['DESCRIPTION'].nunique()
# Out:
# 178
# 180

# %%
sns.catplot(data=cond, y = 'CODE', kind = 'count')

# %%
sns.catplot(data=cond, y = 'DESCRIPTION', kind = 'count')
# Out:
# C:\Users\Mirna Elizondo\anaconda3\envs\condaEnv\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# **What does this tell us?**
# - Bad graphs but we can see that 2 codes are used twice meaning that the code and descriptions may not be 1 to 1 but using Code will cover all conditions
# - Description will still be utilized as described below

# %% [markdown]
# ### Looking into most frequent conditions

# %%
print('Unique values', cond['CODE'].nunique())
print('Most frequent:')
top = cond['CODE'].value_counts().to_frame()
top = top['CODE'].idxmax()
topD = cond['DESCRIPTION'].value_counts().to_frame()
topD = topD['DESCRIPTION'].idxmax()

print('CODE: ',  topC, '\nDESCRIPTION: ', topD)
# Out:
# Unique values 178
# Most frequent:
# CODE:  233604007
# DESCRIPTION:  Otitis media

# %%
n=25
print('List of 25 most frequent values:')
top25 = cond['CODE'].value_counts()[:n].index.tolist()
print(top25)
# Out:
# List of 25 most frequent values:
# [233604007, 427089005, 65363002, 236077008, 284551006, 283371005, 263102004, 254637007, 424132000, 83664006, 48333001, 6072007, 70704007, 65966004, 698754002, 109838007, 363406005, 301011002, 90560007, 443165006, 16114001, 39848009, 47693006, 230265002, 36971009]
# C:\Users\Mirna Elizondo\AppData\Local\Temp\ipykernel_8428\4245495540.py:3: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   top25 = cond['CODE'].value_counts()[:n].index.tolist()

# %% [markdown]
# #### Top 25

# %%
top25 = df_conditions.loc[(df_conditions['CODE'].isin(top25))]
top25 = top25.drop(['START', 'STOP'], axis=1)
top25
# Out:
#                                      PATIENT  \
# 0       f0f3bc8d-ef38-49ce-a2bd-dfdda982b271
# 1       f0f3bc8d-ef38-49ce-a2bd-dfdda982b271
# 43      f58bf921-cba1-475a-b4f8-dc6fa3b8f89c
# 128     f39d31c4-9ba8-4468-9f48-065a8dc13e0f
# 196     da0334da-83d5-443c-9f80-185654a0c534
# ...                                      ...
# 114434  6592de1d-1d0a-46c9-8a45-89e9cadbca27
# 114459  534ed6ac-1178-47ce-a0c4-ecf779613143
# 114475  c9699449-7a8b-400a-8e86-fab6aa7134cb
# 114515  cb03d88e-7f08-46a1-be78-70d9fe8262a7
# 114518  435be43f-cb57-442f-aeb2-51018b030ed0
#
#                                    ENCOUNTER       CODE  \
# 0       d5ee30a9-362f-429e-a87a-ee38d999b0a5   65363002
# 1       8bca6d8a-ab80-4cbf-8abb-46654235f227   65363002
# 43      e97e8d37-7497-4c13-98fd-a4a45655c0bb  233604007
# 128     b059d051-d157-4c83-be89-271808df2ebb  233604007
# 196     a8334fae-0b2c-465b-b162-af1442de4f67  233604007
# ...                                      ...        ...
# 114434  5e8a16d6-f8c9-4372-a6f5-792aca3c9444  233604007
# 114459  5fd18bbd-f098-402b-8d0b-fa3d3237e316  233604007
# 114475  57d8ff2e-b92c-4fb5-bbf4-d7d5f23382b4  233604007
# 114515  30080779-b237-467f-8ca5-e332dec46bda  233604007
# 114518  0483ef7f-bdf6-4763-a5ec-78304113d711   83664006
#
#                                DESCRIPTION  ConditionDuration
# 0                             Otitis media              167.0
# 1                             Otitis media               92.0
# 43                    Pneumonia (disorder)                9.0
# 128                   Pneumonia (disorder)               13.0
# 196                   Pneumonia (disorder)               13.0
# ...                                    ...                ...
# 114434                Pneumonia (disorder)               12.0
# 114459                Pneumonia (disorder)               10.0
# 114475                Pneumonia (disorder)                8.0
# 114515                           Pneumonia                NaN
# 114518  Idiopathic atrophic hypothyroidism                NaN
#
# [3767 rows x 5 columns]

# %%
sns.catplot(data=top25, y = 'CODE', kind = 'count')

# %%
sns.catplot(data=top25, y = 'DESCRIPTION', kind = 'count')

# %% [markdown]
# **What does this tell us?**
#
# - Similar to the N3C data looking at the descriptions gives us insight that multiple conditions can be related, by looking at the code we wouldnt be able to tell that 233604007-Pneumonia (disorder) is assumed to be same as 236077008-Pneumonia
# - The conditions will need to be grouped to include all the variations of the names
# - Although the codes are linked to the OMOP common model, we aim to find the most common conditions that occurred
#     - after patient was reported with a 'COVID-19 related conditions'
#     - to deceased patients since 2021 (COVID-19 Pandemic)
#     - to patients who were reported with 'COVID-19 related conditions' and died

# %% [markdown]
# #### Top 25-50

# %%
print('List of 25-50 most frequent values:')
top25_50 = cond['CODE'].value_counts()[25:50].index.tolist()
print(top25_50)
top25Cond = df_conditions.loc[(df_conditions['CODE'].isin(top25_50))]
top25Cond = top25Cond.drop(['START', 'STOP'], axis=1)
top25Cond
# Out:
# List of 25-50 most frequent values:
# [87628006, 67811000119102, 62564004, 62106007, 431855005, 127013003, 431856006, 90781000119102, 82423001, 126906006, 33737001, 92691004, 241929008, 26929004, 74400008, 428251008, 185086009, 403191005, 408512008, 127295002, 262574004, 7200002, 433144002, 94260004, 47200007]
# C:\Users\Mirna Elizondo\AppData\Local\Temp\ipykernel_8428\4050536118.py:2: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   top25_50 = cond['CODE'].value_counts()[25:50].index.tolist()
#                                      PATIENT  \
# 847     b5fbb0b5-6b9f-45b2-bab0-3630dc3555a3
# 849     b5fbb0b5-6b9f-45b2-bab0-3630dc3555a3
# 851     b83237f3-9ff5-491e-aab4-d63ccff85f85
# 869     46988a9c-9c86-429a-bc4a-b3d14ff321b0
# 870     46988a9c-9c86-429a-bc4a-b3d14ff321b0
# ...                                      ...
# 114494  eec72396-d10e-4b8e-8fb6-25fc1e396031
# 114495  eec72396-d10e-4b8e-8fb6-25fc1e396031
# 114511  cb03d88e-7f08-46a1-be78-70d9fe8262a7
# 114533  2712205f-755e-4897-acb3-926895b7d635
# 114534  2712205f-755e-4897-acb3-926895b7d635
#
#                                    ENCOUNTER            CODE  \
# 847     85fc358b-163c-4e68-a377-3af9b65f9e50  67811000119102
# 849     f77329ae-ea3d-4370-b211-2d37a8c0d03e        62564004
# 851     245bbb25-9086-4343-bf19-d38c1503b697        62106007
# 869     f0f1eb6d-1f96-48fa-86f9-10dd70d4440c       431855005
# 870     f0f1eb6d-1f96-48fa-86f9-10dd70d4440c       127013003
# ...                                      ...             ...
# 114494  fecfa6b7-3e2c-4dbc-897e-4b98cb6f42ba        74400008
# 114495  90df2e31-db07-4f24-a778-f92b5135661b       428251008
# 114511  008d9108-73e7-4e95-8bf8-5fd32c41e926        26929004
# 114533  df9ec01c-f427-46ce-a7b2-21fd83a79836       431855005
# 114534  df9ec01c-f427-46ce-a7b2-21fd83a79836       127013003
#
#                                               DESCRIPTION  ConditionDuration
# 847     Primary small cell malignant neoplasm of lung ...                NaN
# 849                 Concussion with loss of consciousness                NaN
# 851              Concussion with no loss of consciousness               60.0
# 869             Chronic kidney disease stage 1 (disorder)                NaN
# 870                     Diabetic renal disease (disorder)                NaN
# ...                                                   ...                ...
# 114494                                       Appendicitis                NaN
# 114495                            History of appendectomy                NaN
# 114511                     Alzheimer's disease (disorder)                NaN
# 114533          Chronic kidney disease stage 1 (disorder)                NaN
# 114534                  Diabetic renal disease (disorder)                NaN
#
# [4463 rows x 5 columns]

# %%
sns.catplot(data=top25Cond, y = 'CODE', kind = 'count')

# %%
sns.catplot(data=top25Cond, y = 'DESCRIPTION', kind = 'count')
# Out:
# C:\Users\Mirna Elizondo\anaconda3\envs\condaEnv\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# #### Top 50-75

# %%
print('List of 50-75 most frequent values:')
top50_75 = cond['CODE'].value_counts()[50:75].index.tolist()
print(top50_75)
top50Cond = df_conditions.loc[(df_conditions['CODE'].isin(top50_75))]
top50Cond = top50Cond.drop(['START', 'STOP'], axis=1)
top50Cond
# Out:
# List of 50-75 most frequent values:
# [429280009, 1734006, 161622006, 198992004, 200936003, 444470001, 157141000119108, 30832001, 403192003, 239720000, 47505003, 707577004, 190905008, 60951000119105, 698423002, 65275009, 35999006, 225444004, 162573006, 314994000, 449868002, 370247008, 307731004, 284549007, 97331000119101]
# C:\Users\Mirna Elizondo\AppData\Local\Temp\ipykernel_8428\3511391401.py:2: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   top50_75 = cond['CODE'].value_counts()[50:75].index.tolist()
#                                      PATIENT  \
# 845     b5fbb0b5-6b9f-45b2-bab0-3630dc3555a3
# 1578    7b7d2280-354f-4bfa-b1b5-ebe85da184dd
# 1686    4f78c555-7e1f-43d8-8700-646ae81c39f0
# 2786    62a6025a-371d-422b-b417-f72de73268df
# 2789    62a6025a-371d-422b-b417-f72de73268df
# ...                                      ...
# 112547  f854d23e-844c-4d70-820d-a9148ce08f17
# 112947  5288d5b2-d85a-4f79-92ff-efb76ee6a323
# 113525  15798f02-bfaa-4f57-8ec5-245899c903c6
# 113628  e4f40209-6f4b-419a-9c0b-693ef0f9e38e
# 114391  14a24c98-bf8e-479d-91d0-571b66668c38
#
#                                    ENCOUNTER            CODE  \
# 845     e03f688a-2087-42a0-ab6a-177f6314963a       162573006
# 1578    34769144-1500-41ef-90f0-80728fad4509       162573006
# 1686    c433cfcd-f55b-4680-b274-9bff8e68cc1e       162573006
# 2786    28cfbaa9-e495-44d6-b299-62de2e50301e       162573006
# 2789    8c516648-8ae5-4a39-b998-f383f670528f       449868002
# ...                                      ...             ...
# 112547  b3041c7b-76b8-4954-8e44-6931a9c55b3a       198992004
# 112947  80eefe8a-f48a-4357-9df6-c002af277959       449868002
# 113525  73d78ecc-5e8a-49a0-b0a0-39181fec4a55       370247008
# 113628  9ae63d76-910a-4e17-92f8-8cf1a042a715       162573006
# 114391  f3d77b92-cdfd-42a0-af61-bac7ce9c0a97  97331000119101
#
#                                               DESCRIPTION  ConditionDuration
# 845                     Suspected lung cancer (situation)                NaN
# 1578                    Suspected lung cancer (situation)                NaN
# 1686                    Suspected lung cancer (situation)                NaN
# 2786                    Suspected lung cancer (situation)                NaN
# 2789                                 Smokes tobacco daily                NaN
# ...                                                   ...                ...
# 112547                               Antepartum eclampsia               21.0
# 112947                               Smokes tobacco daily                NaN
# 113525                                  Facial laceration               21.0
# 113628                  Suspected lung cancer (situation)                NaN
# 114391  Macular edema and retinopathy due to type 2 di...                NaN
#
# [618 rows x 5 columns]

# %%
sns.catplot(data=top50Cond, y = 'CODE', kind = 'count')

# %%
sns.catplot(data=top50Cond, y = 'DESCRIPTION', kind = 'count')
# Out:
# C:\Users\Mirna Elizondo\anaconda3\envs\condaEnv\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# #### Top 75-100

# %%
print('List of 75-100 most frequent values:')
top75_100 = cond['CODE'].value_counts()[75:100].index.tolist()
print(top75_100)
top75Cond = df_conditions.loc[(df_conditions['CODE'].isin(top75_100))]
top75Cond = top75Cond.drop(['START', 'STOP'], axis=1)
top75Cond
# Out:
# List of 75-100 most frequent values:
# [195967001, 370143000, 95417003, 38822007, 93761005, 403190006, 5602001, 110030002, 359817006, 246677007, 40275004, 444448004, 69896004, 254632001, 192127007, 386661006, 156073000, 162864005, 15777000, 58150001, 267102003, 275272006, 72892002, 19169002, 271737000]
# C:\Users\Mirna Elizondo\AppData\Local\Temp\ipykernel_8428\2539396242.py:2: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   top75_100 = cond['CODE'].value_counts()[75:100].index.tolist()
#                                      PATIENT  \
# 2       f0f3bc8d-ef38-49ce-a2bd-dfdda982b271
# 9       067318a4-db8f-447f-8b6e-f2f61e9baaa5
# 20      ae9efba3-ddc4-43f9-a781-f72019388548
# 28      199c586f-af16-4091-9998-ee4cfc02ee7a
# 35      353016ea-a0ff-4154-85bb-1cf8b6cedf20
# ...                                      ...
# 114516  435be43f-cb57-442f-aeb2-51018b030ed0
# 114517  435be43f-cb57-442f-aeb2-51018b030ed0
# 114519  435be43f-cb57-442f-aeb2-51018b030ed0
# 114526  435be43f-cb57-442f-aeb2-51018b030ed0
# 114531  2712205f-755e-4897-acb3-926895b7d635
#
#                                    ENCOUNTER       CODE  \
# 2       681c380b-3c84-4c55-80a6-db3d9ea12fee  386661006
# 9       1ea74a77-3ad3-4948-a9cc-3084462035d6  386661006
# 20      eeab7c2d-71ba-4e04-af16-87a01dce7d54  386661006
# 28      8333efdf-f7bf-43bb-b73f-2b663d14c1ad  386661006
# 35      8d502eec-afc0-4639-b298-a152a16d492a  386661006
# ...                                      ...        ...
# 114516  973c9957-465a-4e64-9ca1-bd60b57de2c5  162864005
# 114517  be2b20ff-b2c0-4750-bd73-a149aeb20e3e   19169002
# 114519  0483ef7f-bdf6-4763-a5ec-78304113d711  271737000
# 114526  a3232b65-d975-45d1-a9bd-1e89704d7f58  386661006
# 114531  afe4008b-139b-4a3e-aac5-4626840b1f8e  271737000
#
#                                     DESCRIPTION  ConditionDuration
# 2                               Fever (finding)               29.0
# 9                               Fever (finding)               32.0
# 20                              Fever (finding)               35.0
# 28                              Fever (finding)               37.0
# 35                              Fever (finding)               16.0
# ...                                         ...                ...
# 114516  Body mass index 30+ - obesity (finding)                NaN
# 114517           Miscarriage in first trimester                NaN
# 114519                        Anemia (disorder)                NaN
# 114526                          Fever (finding)               31.0
# 114531                        Anemia (disorder)                NaN
#
# [26200 rows x 5 columns]

# %%
sns.catplot(data=top75Cond, y = 'CODE', kind = 'count')

# %%
sns.catplot(data=top75Cond, y = 'DESCRIPTION', kind = 'count')

# %%
print('List of 100-125 most frequent values:')
top100_125 = cond['CODE'].value_counts()[100:125].index.tolist()
print(top100_125)
top100Cond = df_conditions.loc[(df_conditions['CODE'].isin(top100_125))]
top100Cond = top100Cond.drop(['START', 'STOP'], axis=1)
top100Cond
# Out:
# List of 100-125 most frequent values:
# [230690007, 195662009, 446096008, 87433001, 40055000, 53741008, 770349000, 233678006, 254837009, 55680006, 410429000, 57676002, 68962001, 706870000, 444814009, 840544004, 840539006, 44465007, 49727002, 248595008, 267060006, 43878008, 59621000, 25064002, 271825005]
# C:\Users\Mirna Elizondo\AppData\Local\Temp\ipykernel_8428\1038849995.py:2: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   top100_125 = cond['CODE'].value_counts()[100:125].index.tolist()
#                                      PATIENT  \
# 3       f0f3bc8d-ef38-49ce-a2bd-dfdda982b271
# 4       f0f3bc8d-ef38-49ce-a2bd-dfdda982b271
# 5       067318a4-db8f-447f-8b6e-f2f61e9baaa5
# 6       067318a4-db8f-447f-8b6e-f2f61e9baaa5
# 7       067318a4-db8f-447f-8b6e-f2f61e9baaa5
# ...                                      ...
# 114539  2712205f-755e-4897-acb3-926895b7d635
# 114540  2712205f-755e-4897-acb3-926895b7d635
# 114541  2712205f-755e-4897-acb3-926895b7d635
# 114542  2712205f-755e-4897-acb3-926895b7d635
# 114543  2712205f-755e-4897-acb3-926895b7d635
#
#                                    ENCOUNTER       CODE  \
# 3       681c380b-3c84-4c55-80a6-db3d9ea12fee  840544004
# 4       681c380b-3c84-4c55-80a6-db3d9ea12fee  840539006
# 5       adedca64-700b-4fb9-82f1-9cbb658abb73   44465007
# 6       1ea74a77-3ad3-4948-a9cc-3084462035d6   49727002
# 7       1ea74a77-3ad3-4948-a9cc-3084462035d6  248595008
# ...                                      ...        ...
# 114539  a18d0f16-bc12-4897-8844-8c3ebc2464fc  248595008
# 114540  a18d0f16-bc12-4897-8844-8c3ebc2464fc   68962001
# 114541  a18d0f16-bc12-4897-8844-8c3ebc2464fc   57676002
# 114542  a18d0f16-bc12-4897-8844-8c3ebc2464fc  840544004
# 114543  a18d0f16-bc12-4897-8844-8c3ebc2464fc  840539006
#
#                      DESCRIPTION  ConditionDuration
# 3             Suspected COVID-19                0.0
# 4                       COVID-19               29.0
# 5                Sprain of ankle               14.0
# 6                Cough (finding)               32.0
# 7       Sputum finding (finding)               32.0
# ...                          ...                ...
# 114539  Sputum finding (finding)               28.0
# 114540     Muscle pain (finding)               28.0
# 114541      Joint pain (finding)               28.0
# 114542        Suspected COVID-19                0.0
# 114543                  COVID-19               28.0
#
# [46554 rows x 5 columns]

# %%
sns.catplot(data=top100Cond, y = 'CODE', kind = 'count')

# %%
sns.catplot(data=top100Cond, y = 'DESCRIPTION', kind = 'count')

# %%
print('List of 125-150 most frequent values:')
top125_150 = cond['CODE'].value_counts()[125:150].index.tolist()
print(top125_150)
top125Cond = df_conditions.loc[(df_conditions['CODE'].isin(top125_150))]
top125Cond = top125Cond.drop(['START', 'STOP'], axis=1)
top125Cond
# Out:
# List of 100-125 most frequent values:
# [84229001, 422587007, 249497008, 36955009, 68235000, 267036007, 56018004, 389087006, 429007001, 239873007, 232353008, 49436004, 64859006, 128613002, 703151001, 75498004, 368581000119106, 1501000119109, 201834006, 84757009, 234466008, 196416002, 68496003, 713197008, 132281000119108]
# C:\Users\Mirna Elizondo\AppData\Local\Temp\ipykernel_8428\2173105901.py:2: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   top125_150 = cond['CODE'].value_counts()[125:150].index.tolist()
#                                      PATIENT  \
# 17      ae9efba3-ddc4-43f9-a781-f72019388548
# 18      ae9efba3-ddc4-43f9-a781-f72019388548
# 19      ae9efba3-ddc4-43f9-a781-f72019388548
# 21      ae9efba3-ddc4-43f9-a781-f72019388548
# 26      199c586f-af16-4091-9998-ee4cfc02ee7a
# ...                                      ...
# 114476  c9699449-7a8b-400a-8e86-fab6aa7134cb
# 114486  4e5d67bf-0f2e-4158-af57-413e276c84dc
# 114488  4e5d67bf-0f2e-4158-af57-413e276c84dc
# 114514  cb03d88e-7f08-46a1-be78-70d9fe8262a7
# 114537  2712205f-755e-4897-acb3-926895b7d635
#
#                                    ENCOUNTER       CODE  \
# 17      eeab7c2d-71ba-4e04-af16-87a01dce7d54   84229001
# 18      eeab7c2d-71ba-4e04-af16-87a01dce7d54  422587007
# 19      eeab7c2d-71ba-4e04-af16-87a01dce7d54  249497008
# 21      eeab7c2d-71ba-4e04-af16-87a01dce7d54   36955009
# 26      8333efdf-f7bf-43bb-b73f-2b663d14c1ad  422587007
# ...                                      ...        ...
# 114476  57d8ff2e-b92c-4fb5-bbf4-d7d5f23382b4  389087006
# 114486  b179344f-f271-4f52-acca-427ae71b23ac   84229001
# 114488  b179344f-f271-4f52-acca-427ae71b23ac   36955009
# 114514  778f9a0f-183b-4db3-b11c-0c3b8fc69f8a   64859006
# 114537  35b1fe82-49ba-42ab-9f66-3644f472c08d   49436004
#
#                        DESCRIPTION  ConditionDuration
# 17               Fatigue (finding)               35.0
# 18                Nausea (finding)               35.0
# 19      Vomiting symptom (finding)               35.0
# 21         Loss of taste (finding)               35.0
# 26                Nausea (finding)               37.0
# ...                            ...                ...
# 114476        Hypoxemia (disorder)                NaN
# 114486           Fatigue (finding)               18.0
# 114488     Loss of taste (finding)               18.0
# 114514     Osteoporosis (disorder)                NaN
# 114537         Atrial Fibrillation                NaN
#
# [21804 rows x 5 columns]

# %%
sns.catplot(data=top125Cond, y = 'CODE', kind = 'count')

# %%
sns.catplot(data=top125Cond, y = 'DESCRIPTION', kind = 'count')
# Out:
# C:\Users\Mirna Elizondo\anaconda3\envs\condaEnv\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   self._figure.tight_layout(*args, **kwargs)

# %%
print('List of 150-178 most frequent values:')
top150_178 = cond['CODE'].value_counts()[125:150].index.tolist()
print(top150_178)
top150Cond = df_conditions.loc[(df_conditions['CODE'].isin(top150_178))]
top150Cond = top150Cond.drop(['START', 'STOP'], axis=1)
top150Cond
# Out:
# List of 150-178 most frequent values:
# [84229001, 422587007, 249497008, 36955009, 68235000, 267036007, 56018004, 389087006, 429007001, 239873007, 232353008, 49436004, 64859006, 128613002, 703151001, 75498004, 368581000119106, 1501000119109, 201834006, 84757009, 234466008, 196416002, 68496003, 713197008, 132281000119108]
# C:\Users\Mirna Elizondo\AppData\Local\Temp\ipykernel_8428\318471414.py:2: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   top150_178 = cond['CODE'].value_counts()[125:150].index.tolist()
#                                      PATIENT  \
# 17      ae9efba3-ddc4-43f9-a781-f72019388548
# 18      ae9efba3-ddc4-43f9-a781-f72019388548
# 19      ae9efba3-ddc4-43f9-a781-f72019388548
# 21      ae9efba3-ddc4-43f9-a781-f72019388548
# 26      199c586f-af16-4091-9998-ee4cfc02ee7a
# ...                                      ...
# 114476  c9699449-7a8b-400a-8e86-fab6aa7134cb
# 114486  4e5d67bf-0f2e-4158-af57-413e276c84dc
# 114488  4e5d67bf-0f2e-4158-af57-413e276c84dc
# 114514  cb03d88e-7f08-46a1-be78-70d9fe8262a7
# 114537  2712205f-755e-4897-acb3-926895b7d635
#
#                                    ENCOUNTER       CODE  \
# 17      eeab7c2d-71ba-4e04-af16-87a01dce7d54   84229001
# 18      eeab7c2d-71ba-4e04-af16-87a01dce7d54  422587007
# 19      eeab7c2d-71ba-4e04-af16-87a01dce7d54  249497008
# 21      eeab7c2d-71ba-4e04-af16-87a01dce7d54   36955009
# 26      8333efdf-f7bf-43bb-b73f-2b663d14c1ad  422587007
# ...                                      ...        ...
# 114476  57d8ff2e-b92c-4fb5-bbf4-d7d5f23382b4  389087006
# 114486  b179344f-f271-4f52-acca-427ae71b23ac   84229001
# 114488  b179344f-f271-4f52-acca-427ae71b23ac   36955009
# 114514  778f9a0f-183b-4db3-b11c-0c3b8fc69f8a   64859006
# 114537  35b1fe82-49ba-42ab-9f66-3644f472c08d   49436004
#
#                        DESCRIPTION  ConditionDuration
# 17               Fatigue (finding)               35.0
# 18                Nausea (finding)               35.0
# 19      Vomiting symptom (finding)               35.0
# 21         Loss of taste (finding)               35.0
# 26                Nausea (finding)               37.0
# ...                            ...                ...
# 114476        Hypoxemia (disorder)                NaN
# 114486           Fatigue (finding)               18.0
# 114488     Loss of taste (finding)               18.0
# 114514     Osteoporosis (disorder)                NaN
# 114537         Atrial Fibrillation                NaN
#
# [21804 rows x 5 columns]

# %% [markdown]
# ## Observations (Observations)

# %% [markdown]
# ## Procedures (Procedures)

# %% [markdown]
# ## Medications (Drugs)

# %% [markdown]
# ## Encounters (Visits)

# %% [markdown]
# ## Immunizations
# **Is not included in N3C, but from our prior work immunizations was a feature selected from the drugs dataset**

# %% [markdown]
# ## Allergies
# **Is not included in N3C, looking into it here to see if theres anything interesting that could be included in N3C**

# %% [markdown]
# ## Devices
# **Is not included in N3C, looking into it here to see if theres anything interesting that could be included in N3C**
